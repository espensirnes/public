# %% [markdown]
# # Eurostat

# %%
import eurostat
toc = eurostat.get_toc_df()
toc[['Electricity' in i for i in toc['title']]]
# Out:
#                                                    title            code  \
# 5238   Electricity, gas and water by employment size ...  sbs_sc_2d_el95
# 5239   Electricity, gas and water by employment size ...  sbs_sc_2d_el02
# 7115   Electricity production capacities by main fuel...     nrg_inf_epc
# 7116   Electricity production capacities for renewabl...   nrg_inf_epcrw
# 7117   Electricity production capacities for combusti...    nrg_inf_epct
# 7151            Electricity available to internal market      nrg_cb_eim
# 7198   Electricity prices for household consumers - b...      nrg_pc_204
# 7199   Electricity prices for non-household consumers...      nrg_pc_205
# 7206   Electricity prices components for household co...    nrg_pc_204_c
# 7207   Electricity prices components for non-househol...    nrg_pc_205_c
# 7212   Electricity prices for domestic consumers - bi...    nrg_pc_204_h
# 7213   Electricity prices for industrial consumers - ...    nrg_pc_205_h
# 7214   Electricity - marker prices - bi-annual data (...    nrg_pc_206_h
# 8670                  Electricity prices by type of user        ten00117
# 10241  Electricity production capacities by main fuel...     nrg_inf_epc
# 10285  Electricity production capacities for renewabl...   nrg_inf_epcrw
#
#           type last update of data last table structure change data start  \
# 5238   dataset          24.05.2016                  08.02.2021       1995
# 5239   dataset          24.05.2016                  08.02.2021       2002
# 7115   dataset          10.03.2022                  27.01.2022       1990
# 7116   dataset          07.03.2022                  27.01.2022       1990
# 7117   dataset          10.03.2022                  27.01.2022       1990
# 7151   dataset          29.03.2022                  11.03.2022    2008M01
# 7198   dataset          29.03.2022                  23.03.2022     2007S1
# 7199   dataset          29.03.2022                  23.03.2022     2007S1
# 7206   dataset          25.03.2022                  23.03.2022     2007S2
# 7207   dataset          25.03.2022                  23.03.2022     2007S2
# 7212   dataset          28.05.2021                  28.05.2021     1985S1
# 7213   dataset          28.05.2021                  28.05.2021     1985S1
# 7214   dataset          18.06.2021                  18.06.2021     1991S2
# 8670     table          29.03.2022                  29.03.2022       2009
# 10241  dataset          10.03.2022                  27.01.2022       1990
# 10285  dataset          07.03.2022                  27.01.2022       1990
#
#       data end
# 5238      2001
# 5239      2007
# 7115      2020
# 7116      2020
# 7117      2020
# 7151   2022M01
# 7198    2021S2
# 7199    2021S2
# 7206      2021
# 7207      2021
# 7212    2007S2
# 7213    2007S2
# 7214    2007S1
# 8670      2020
# 10241     2020
# 10285     2020

# %%
def thick_line(symbol,ax,col=None):
    labels=[i._label for i in ax.lines]  #makes a list of symbols in the order of lines in the axis object
    i=labels.index(symbol)               #identifies at which position symbol is located
    ax.lines[i].set_linewidth(5)         #sets the line with of the line at position i to 5 
    ax.lines[i].set_alpha(1)             #sets removes transparancy of the line at position i to 5 
    if not col is None:
        ax.lines[i].set_color(col)

# %%
import eurostat
import numpy as np
df = eurostat.get_data_df('nrg_pc_205')
df=df[(df['tax']=='X_TAX')*
   (df['consom']=='4162906')*
   (df['currency']=='EUR')*
     (df!=0).all(axis=1)]

cols=['geo\\time']+[f"{y}S{s}" for y in range(2007,2022) for s in [1,2]][:-1]
df=df[cols].set_index('geo\\time').transpose()
ax=df.plot(alpha=0.3,figsize=(20, 10))
ax.set_ylim([0, 0.125])
thick_line('DE',ax)
thick_line('NO',ax,'darkblue')
thick_line('NL',ax)
thick_line('UK',ax)
thick_line('SE',ax,'yellow')
thick_line('DK',ax,'red')
ax.legend(loc='lower left',frameon=False,ncol=8)

# %% [markdown]
# # SSB-nordpool

# %%
import pandas as pd
data = pd.read_csv("kraft pris-prod.csv", sep=';')
data
# Out:
#            Dato     Pris  Total kraftproduksjon   Import  Eksport
# 0    2010-01-01   411.32               14825249   955497   802312
# 1    2010-02-01   642.71               12624913   936811   411703
# 2    2010-03-01   484.36               11229016  1447281   150579
# 3    2010-04-01   385.48                8708195  1657794   118342
# 4    2010-05-01   355.46                7599771  2077840   284937
# ..          ...      ...                    ...      ...      ...
# 138  2021-07-01   576.47               11050841   351895  2587240
# 139  2021-08-01   748.34               10398598   587506  1771055
# 140  2021-09-01  1083.67               11234852   419531  2163714
# 141  2021-10-01   961.13               12359480   979048  2238711
# 142  2021-11-01  1063.28               14420057   671276  2681304
#
# [143 rows x 5 columns]

# %%
from statsmodels.regression.linear_model import OLS
preF2021=data['Dato']<'2021-06-01'
data['Nettoeksport %'] = (data['Eksport']-data['Import'])/data['Total kraftproduksjon']
y=pd.DataFrame(data['Nettoeksport %'])
y['Intercept']=1

res=OLS(data['Pris'][preF2021],y[preF2021]).fit()

print(res.summary())
# Out:
# c:\program files\python38\lib\site-packages\statsmodels\compat\pandas.py:65: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import Int64Index as NumericIndex
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   Pris   R-squared:                       0.351
# Model:                            OLS   Adj. R-squared:                  0.346
# Method:                 Least Squares   F-statistic:                     72.86
# Date:                Wed, 30 Mar 2022   Prob (F-statistic):           2.54e-14
# Time:                        10:37:56   Log-Likelihood:                -827.86
# No. Observations:                 137   AIC:                             1660.
# Df Residuals:                     135   BIC:                             1666.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Nettoeksport %  -739.9745     86.688     -8.536      0.000    -911.418    -568.532
# Intercept        343.5591     10.628     32.325      0.000     322.540     364.578
# ==============================================================================
# Omnibus:                        6.627   Durbin-Watson:                   0.565
# Prob(Omnibus):                  0.036   Jarque-Bera (JB):                6.185
# Skew:                           0.481   Prob(JB):                       0.0454
# Kurtosis:                       3.397   Cond. No.                         9.93
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
import numpy as np
from matplotlib import pyplot as plt




fig,ax=plt.subplots()


ax.set_ylabel('Pris')
ax.set_xlabel('Nettoeksport')



ax.scatter(data['Nettoeksport %'][preF2021], data['Pris'][preF2021],               label='2010-2021',    color='#5376c2')
ax.scatter(data['Nettoeksport %'][preF2021==False], data['Pris'][preF2021==False], label='Høsten 2021',    color='#c25353')

x=np.linspace(min(data['Nettoeksport %']),max(data['Nettoeksport %']),100)

ax.plot(x,res.params[1]+res.params[0]*x , label='regressjonslinje',    color='#ed0909')

#5. adding legend in the upper left corner:
ax.legend(loc='upper left',frameon=False)

# %% [markdown]
# # Estimere etterspørselskurven

# %%
data['År']=pd.to_datetime(data['Dato']).dt.year
data_annual=data.groupby(data['År'])[['År', 'Pris','Total kraftproduksjon']].transform('mean')
data_annual=data_annual[['År', 'Pris','Total kraftproduksjon']].drop_duplicates()
data_annual
# Out:
#          År        Pris  Total kraftproduksjon
# 0    2010.0  436.007500           1.037062e+07
# 12   2011.0  363.195833           1.067870e+07
# 24   2012.0  221.833333           1.232046e+07
# 36   2013.0  292.284167           1.118666e+07
# 48   2014.0  228.901667           1.186058e+07
# 60   2015.0  177.392500           1.208507e+07
# 72   2016.0  242.450833           1.246095e+07
# 84   2017.0  270.880000           1.243776e+07
# 96   2018.0  419.030000           1.223708e+07
# 108  2019.0  387.015833           1.121955e+07
# 120  2020.0   97.705833           1.285010e+07
# 132  2021.0  664.250000           1.282277e+07

# %% [markdown]
# ## Finner log

# %%
data_annual['Log total kraftproduksjon']=np.log(data_annual['Total kraftproduksjon'])
data_annual['Log pris']=np.log(data_annual['Pris'])
data_annual
# Out:
#          År        Pris  Total kraftproduksjon  Log total kraftproduksjon  \
# 0    2010.0  436.007500           1.037062e+07                  16.154487
# 12   2011.0  363.195833           1.067870e+07                  16.183762
# 24   2012.0  221.833333           1.232046e+07                  16.326772
# 36   2013.0  292.284167           1.118666e+07                  16.230232
# 48   2014.0  228.901667           1.186058e+07                  16.288731
# 60   2015.0  177.392500           1.208507e+07                  16.307482
# 72   2016.0  242.450833           1.246095e+07                  16.338111
# 84   2017.0  270.880000           1.243776e+07                  16.336248
# 96   2018.0  419.030000           1.223708e+07                  16.319981
# 108  2019.0  387.015833           1.121955e+07                  16.233169
# 120  2020.0   97.705833           1.285010e+07                  16.368862
# 132  2021.0  664.250000           1.282277e+07                  16.366733
#
#      Log pris
# 0    6.077659
# 12   5.894942
# 24   5.401926
# 36   5.677727
# 48   5.433293
# 60   5.178365
# 72   5.490799
# 84   5.601676
# 96   6.037943
# 108  5.958466
# 120  4.581961
# 132  6.498659

# %% [markdown]
# ## Estimerer etterspørselens priselastisitet

# %%
fig,ax=plt.subplots()

ax.set_ylabel('Pris')
ax.set_xlabel('Total kraftproduksjon')



ax.scatter((data_annual['Log total kraftproduksjon']), data_annual['Log pris'], label='Observasjoner', color='#5376c2')

ax.legend(loc='upper left',frameon=False)

# %%
y=pd.DataFrame(data_annual['Log total kraftproduksjon'])
y['Intercept']=1

res=OLS(data_annual['Log pris'],y).fit()

print(res.summary())

x=np.linspace(min(data_annual['Log total kraftproduksjon']),max(data_annual['Log total kraftproduksjon']),100)

ax.plot(x,res.params[1]+res.params[0]*x , label='regressjonslinje',    color='#ed0909')

#5. adding legend in the upper left corner:
fig
# Out:
# c:\program files\python38\lib\site-packages\scipy\stats\stats.py:1534: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=12
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               Log pris   R-squared:                       0.126
# Model:                            OLS   Adj. R-squared:                  0.038
# Method:                 Least Squares   F-statistic:                     1.439
# Date:                Wed, 30 Mar 2022   Prob (F-statistic):              0.258
# Time:                        10:41:42   Log-Likelihood:                -7.2900
# No. Observations:                  12   AIC:                             18.58
# Df Residuals:                      10   BIC:                             19.55
# Df Model:                           1
# Covariance Type:            nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Log total kraftproduksjon    -2.4777      2.065     -1.200      0.258      -7.079       2.124
# Intercept                    46.0092     33.639      1.368      0.201     -28.943     120.961
# ==============================================================================
# Omnibus:                        3.294   Durbin-Watson:                   2.208
# Prob(Omnibus):                  0.193   Jarque-Bera (JB):                0.847
# Skew:                           0.460   Prob(JB):                        0.655
# Kurtosis:                       3.921   Cond. No.                     3.92e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.92e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ## Fjerner uteligger

# %%
flter=data_annual['År']<2021

y=pd.DataFrame(data_annual['Log total kraftproduksjon'])[flter]
y['Intercept']=1

res=OLS(data_annual['Log pris'][flter],y).fit()

print(res.summary())

ax.plot(x,res.params[1]+res.params[0]*x , label='regressjonslinje',    color='#448550')

#5. adding legend in the upper left corner:
fig
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               Log pris   R-squared:                       0.471
# Model:                            OLS   Adj. R-squared:                  0.412
# Method:                 Least Squares   F-statistic:                     8.004
# Date:                Wed, 30 Mar 2022   Prob (F-statistic):             0.0197
# Time:                        10:42:21   Log-Likelihood:                -2.5319
# No. Observations:                  11   AIC:                             9.064
# Df Residuals:                       9   BIC:                             9.860
# Df Model:                           1
# Covariance Type:            nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Log total kraftproduksjon    -4.3156      1.525     -2.829      0.020      -7.766      -0.865
# Intercept                    75.8368     24.835      3.054      0.014      19.657     132.017
# ==============================================================================
# Omnibus:                        1.312   Durbin-Watson:                   1.218
# Prob(Omnibus):                  0.519   Jarque-Bera (JB):                0.056
# Skew:                           0.075   Prob(JB):                        0.972
# Kurtosis:                       3.318   Cond. No.                     4.00e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large,  4e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# c:\program files\python38\lib\site-packages\scipy\stats\stats.py:1534: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=11
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "

# %% [markdown]
# ## Etterspørselselastisitet

# %%
flter=data_annual['År']<2021

y=pd.DataFrame(data_annual['Log pris'])[flter]
y['Intercept']=1

res=OLS(data_annual['Log total kraftproduksjon'][flter],y).fit()
print(res.summary())
# Out:
#                                 OLS Regression Results
# =====================================================================================
# Dep. Variable:     Log total kraftproduksjon   R-squared:                       0.471
# Model:                                   OLS   Adj. R-squared:                  0.412
# Method:                        Least Squares   F-statistic:                     8.004
# Date:                       Wed, 30 Mar 2022   Prob (F-statistic):             0.0197
# Time:                               10:58:39   Log-Likelihood:                 17.697
# No. Observations:                         11   AIC:                            -31.39
# Df Residuals:                              9   BIC:                            -30.60
# Df Model:                                  1
# Covariance Type:                   nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Log pris      -0.1091      0.039     -2.829      0.020      -0.196      -0.022
# Intercept     16.8889      0.216     78.344      0.000      16.401      17.377
# ==============================================================================
# Omnibus:                        0.506   Durbin-Watson:                   1.092
# Prob(Omnibus):                  0.777   Jarque-Bera (JB):                0.549
# Skew:                           0.297   Prob(JB):                        0.760
# Kurtosis:                       2.080   Cond. No.                         77.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# c:\program files\python38\lib\site-packages\scipy\stats\stats.py:1534: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=11
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "

# %% [markdown]
# ## Mulig oppgave: Finn priseffekt av utenlandskablene
